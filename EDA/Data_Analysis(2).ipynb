# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
branded_food = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/branded_food.csv")
branded_food.shape
# Out:
# <ipython-input-31-26732e216305>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_food = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/branded_food.csv")
# (1958978, 12)

# %%
branded_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958978 entries, 0 to 1958977
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   fdc_id                 int64
#  1   brand_owner            object
#  2   brand_name             object
#  3   gtin_upc               object
#  4   ingredients            object
#  5   serving_size           float64
#  6   serving_size_unit      object
#  7   branded_food_category  object
#  8   data_source            object
#  9   modified_date          object
#  10  available_date         object
#  11  market_country         object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 179.3+ MB

# %%
branded_food.describe()
# Out:
#              fdc_id  serving_size
# count  1.958978e+06  1.958978e+06
# mean   1.579675e+06  3.469717e+02
# std    6.729895e+05  2.587807e+05
# min    3.446040e+05  0.000000e+00
# 25%    1.113183e+06  2.800000e+01
# 50%    1.615666e+06  4.500000e+01
# 75%    2.139385e+06  1.130000e+02
# max    2.688921e+06  2.561132e+08

# %%
nutrient = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/nutrient.csv")
nutrient.shape
# Out:
# (477, 5)

# %%
nutrient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            477 non-null    int64
#  1   name          477 non-null    object
#  2   unit_name     477 non-null    object
#  3   nutrient_nbr  477 non-null    float64
#  4   rank          477 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 18.8+ KB

# %%
nutrient['name'].value_counts()
# Out:
# name
# Oligosaccharides                    2
# Energy                              2
# Vitamin E                           2
# Energy (Atwater General Factors)    1
# MUFA 16:1 c                         1
#                                    ..
# Vanadium, V                         1
# Titanium, Ti                        1
# Tin, Sn                             1
# Strontium, Sr                       1
# Glutathione                         1
# Name: count, Length: 474, dtype: int64

# %%
nutrient.describe()
# Out:
#                 id  nutrient_nbr           rank
# count   477.000000    477.000000     477.000000
# mean   1318.348008    510.561824  231606.493562
# std     303.611477    213.953788  407543.951405
# min    1001.000000    200.000000      50.000000
# 25%    1120.000000    314.000000    7290.000000
# 50%    1239.000000    505.000000   14675.000000
# 75%    1359.000000    690.000000   22700.000000
# max    2069.000000    961.000000  999999.000000

# %%
nutrient_incoming_name = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/nutrient_incoming_name.csv")
nutrient_incoming_name.shape
# Out:
# (730, 3)

# %%
nutrient_incoming_name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           730 non-null    int64
#  1   name         730 non-null    object
#  2   nutrient_id  730 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 17.2+ KB

# %%
nutrient_incoming_name.describe()
# Out:
#                 id  nutrient_id
# count   730.000000   730.000000
# mean   1378.964384  1231.905479
# std     221.326067   216.451620
# min    1000.000000  1002.000000
# 25%    1192.250000  1107.000000
# 50%    1374.500000  1212.000000
# 75%    1559.750000  1278.000000
# max    1789.000000  2033.000000

# %%
microbe = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/microbe.csv")
microbe.shape
# Out:
# (13, 6)

# %%
microbe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            13 non-null     int64
#  1   foodId        13 non-null     int64
#  2   method        13 non-null     object
#  3   microbe_code  13 non-null     object
#  4   min_value     13 non-null     int64
#  5   uom           11 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 752.0+ bytes

# %%
microbe.describe()
# Out:
#              id        foodId   min_value
# count  13.00000  1.300000e+01        13.0
# mean    7.00000  2.453331e+06  10000000.0
# std     3.89444  1.378042e+05         0.0
# min     1.00000  2.331974e+06  10000000.0
# 25%     4.00000  2.337521e+06  10000000.0
# 50%     7.00000  2.371448e+06  10000000.0
# 75%    10.00000  2.613095e+06  10000000.0
# max    13.00000  2.663163e+06  10000000.0

# %%
measure_unit = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/measure_unit.csv")
measure_unit.shape
# Out:
# (122, 2)

# %%
measure_unit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      122 non-null    int64
#  1   name    122 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.0+ KB

# %%
measure_unit.describe()
# Out:
#                 id
# count   122.000000
# mean   1133.270492
# std     810.052422
# min    1000.000000
# 25%    1030.250000
# 50%    1060.500000
# 75%    1090.750000
# max    9999.000000

# %%
food = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/food.csv")
food.shape
# Out:
# (1958978, 6)

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958978 entries, 0 to 1958977
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   fdc_id            int64
#  1   data_type         object
#  2   description       object
#  3   publication_date  object
#  4   market_country    object
#  5   microbe_data      object
# dtypes: int64(1), object(5)
# memory usage: 89.7+ MB

# %%
food.describe()
# Out:
#              fdc_id
# count  1.958978e+06
# mean   1.579675e+06
# std    6.729895e+05
# min    3.446040e+05
# 25%    1.113183e+06
# 50%    1.615666e+06
# 75%    2.139385e+06
# max    2.688921e+06

# %%
food_update_log_entry = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/food_update_log_entry.csv")
food_update_log_entry.shape
# Out:
# (1958978, 3)

# %%
food_update_log_entry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1958978 entries, 0 to 1958977
# Data columns (total 3 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            int64
#  1   description   object
#  2   last_updated  object
# dtypes: int64(1), object(2)
# memory usage: 44.8+ MB

# %%
food_update_log_entry.describe()
# Out:
#                  id
# count  1.958978e+06
# mean   1.579675e+06
# std    6.729895e+05
# min    3.446040e+05
# 25%    1.113183e+06
# 50%    1.615666e+06
# 75%    2.139385e+06
# max    2.688921e+06

# %%
food_nutrient = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/food_nutrient.csv")
food_nutrient.shape
# Out:
# (25301180, 5)

# %%
food_nutrient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25301180 entries, 0 to 25301179
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             int64
#  1   fdc_id         int64
#  2   nutrient_id    int64
#  3   amount         float64
#  4   derivation_id  float64
# dtypes: float64(2), int64(3)
# memory usage: 965.2 MB

# %%
food_nutrient.describe()
# Out:
#                  id        fdc_id   nutrient_id        amount  derivation_id
# count  2.530118e+07  2.530118e+07  2.530118e+07  2.530118e+07   2.530035e+07
# mean   1.931166e+07  1.599889e+06  1.171715e+03  8.029750e+02   7.176120e+01
# std    8.883172e+06  6.872642e+05  2.456225e+02  1.518172e+06   2.467400e+00
# min    2.684218e+06  3.446040e+05  1.003000e+03  0.000000e+00   7.000000e+01
# 25%    1.348010e+07  1.116882e+06  1.008000e+03  0.000000e+00   7.000000e+01
# 50%    1.998762e+07  1.669860e+06  1.092000e+03  4.170000e+00   7.000000e+01
# 75%    2.653942e+07  2.161720e+06  1.253000e+03  4.333000e+01   7.500000e+01
# max    3.384979e+07  2.688921e+06  2.068000e+03  7.500000e+09   7.900000e+01

# %%
food_attribute = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/food_attribute.csv")
food_attribute.shape
# Out:
# (2377616, 4)

# %%
food_attribute.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2377616 entries, 0 to 2377615
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      int64
#  1   fdc_id  int64
#  2   name    object
#  3   value   int64
# dtypes: int64(3), object(1)
# memory usage: 72.6+ MB

# %%
food_attribute.describe()
# Out:
#                  id        fdc_id         value
# count  2.377616e+06  2.377616e+06  2.377616e+06
# mean   1.920773e+06  1.800315e+06  6.710768e+00
# std    8.464165e+05  5.941442e+05  3.287783e+00
# min    2.874800e+04  6.049740e+05  1.000000e+00
# 25%    1.268150e+06  1.305081e+06  4.000000e+00
# 50%    1.974942e+06  1.860188e+06  6.000000e+00
# 75%    2.629509e+06  2.335804e+06  1.000000e+01
# max    3.267811e+06  2.688920e+06  2.000000e+01

# %%
food_attribute_type = pd.read_csv("/content/drive/MyDrive/FoodData_Central_Clean/food_attribute_type.csv")
food_attribute_type.shape
# Out:
# (5, 3)

# %%
food_attribute_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           5 non-null      int64
#  1   name         5 non-null      object
#  2   description  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
food_attribute_type.describe()
# Out:
#                 id
# count     5.000000
# mean   1000.000000
# std       1.581139
# min     998.000000
# 25%     999.000000
# 50%    1000.000000
# 75%    1001.000000
# max    1002.000000
